# %% [markdown]
# # Functions
#
# The problems in this notebook correpond to the <a href="../lectures/Writing Functions.ipynb">Writing Functions</a> notebook.

# %% [markdown]
# ## Basic Problems
#
# 1. Write a function that takes in three arguments and subtracts the second from the first then adds the third.

# %%
## Code here

def function1(x,y,z):
    print(x-y+z)

function1(5,3,1)
# Out:
# 3

# %% [markdown]
# 2. Write a function that takes in an $x$ and $y$ and tells you whether or not the point $(x,y)$ is above the line $y = x + 2$.

# %%
## Code here

def isaboveline(x,y):
    if y > x + 2:
        print("This point is above the line y=x+2.")
    else:
        print("This point is not above the line y=x+2.")

isaboveline(2,1000)
# Out:
# This point is above the line y=x+2.

# %% [markdown]
# 3. Write a function that takes in an argument and tells you whether it is an `str`. Hint: Remember the `type` function in python.

# %%
## Code here


def isstring(x):
    if type(x) == str:
        print("It's a string")
    else:
        print("It's not a string")

isstring("This is a string")

isstring(4315)
# Out:
# It's a string
# It's not a string

# %% [markdown]
# 4. Write a function that takes in a name and says hello to that name.

# %%
## Code here

def hello(x):
    if type(x) == str:
        print(f"Hello, {x}.")


hello("Kevin")

## This uses an f-string for python to insert variables into string.
# Out:
# Hello, Kevin.

# %% [markdown]
# 5. Write a function that takes in a number and a value, `p`, and returns a $-1$ if the number is below `p` and a $1$ if the number is above `p`.

# %%
## Code here

def belowabove(x,p):
    if x < p:
        return -1
    if x > p: 
        return 1
    if x == p:
        print("They are equal")


# Not so hard to even do!
# Out:
# They are equal

# %% [markdown]
# ## More Advanced Problems
#
# 1. Taxable income is determined on a bracket system, where the taxes you owe are determined by  the bracket below:
# <img src = "single_tax.png" style="width:60%"></img>
# Write a function that takes in someone's taxable income and computes how much they owe the federal government.

# %%
## Code here


def bracket(x):
    if x <= 9875:
        return 10
    if x <= 40125:
        return 12
    if x <= 85525:
        return 22
    if x<= 163300:
        return 24
    if x<= 207350:
        return 32
    if x<= 518400:
        return 35
    if x >= 518401:
        return 37
# Out:
# 24

# %%
## Code here

def tax_owed(x):
    if bracket(x) == 10:
        return bracket(x)*0.10*x
    if bracket(x) == 12:
        return 987.50 + 0.12* (x-9875)
    if bracket(x) == 22:
        return 4617.50 + 0.22 * (x-40125)
    if bracket(x) == 24:
        return 14605.50 + 0.24*(x-85525)
    if bracket(x) == 32:
        return 33271.50 + 0.32*(x-163300)
    if bracket(x) == 35:
        return 47367.50 + 0.35*(x-207350)
    if bracket(x) == 37:
        return 156235 + 0.37*(x - 518400)

tax_owed(518401)
# Out:
# 156235.37

# %%
## Code here

# %% [markdown]
# 2. You can approximate $\pi$ with the following sum:
# $$
# \sum_{i=0}^N \frac{8}{\left( 4i + 1 \right) \left( 4i + 3 \right)},
# $$
# Write a function that takes in a value for $N$ and returns an approximation of $\pi$.

# %%
## Code here

def approxpi(N):
    i = 0
    x = 0
    while i <= N:
        y = 8 / ((4*i+1)*(4*i+3))
        x += y
        i += 1
    return x


approxpi(10000000)
# Out:
# 3.141592603588103

# %%
## Code here

# %%
## Code here

# %% [markdown]
# 3. Write a function that takes in a list of words, and returns a word count dictionary that contains the number of times each unique word shows up in the list. Test it on the list of words stored in `sample_words`.

# %%
sample_words = ["apple", "banana", "apple", "computer", "computer",
               "programming", "language", "Obama", "Bush", "Trump",
               "Eisenhower", "president", "president", "president",
               "president", "dog", "dog", "cat", "duck", "duck", "goose",
               "baseball", "basketball", "football", "hockey", "soccer",
               "sports", "lebron", "james", "darius", "garland"]

len(sample_words)
# Out:
# 31

# %%
## Code here

def count_repeats(x):
    count = {}
    for i in x:
        if not i in count: 
            count[i] = 1
        else:
            count[i] +=1
    return count
    
count_repeats(sample_words)
# Out:
# {'apple': 2,
#  'banana': 1,
#  'computer': 2,
#  'programming': 1,
#  'language': 1,
#  'Obama': 1,
#  'Bush': 1,
#  'Trump': 1,
#  'Eisenhower': 1,
#  'president': 4,
#  'dog': 2,
#  'cat': 1,
#  'duck': 2,
#  'goose': 1,
#  'baseball': 1,
#  'basketball': 1,
#  'football': 1,
#  'hockey': 1,
#  'soccer': 1,
#  'sports': 1,
#  'lebron': 1,
#  'james': 1,
#  'darius': 1,
#  'garland': 1}

# %%
## Code here
# Out:
# 'garland'

# %%
## Code here

# %% [markdown]
# --------------------------
#
# This notebook was written for the Erd&#337;s Institute C&#337;de Data Science Boot Camp by Matthew Osborne, Ph. D., 2022.
#
# Any potential redistributors must seek and receive permission from Matthew Tyler Osborne, Ph.D. prior to redistribution. Redistribution of the material contained in this repository is conditional on acknowledgement of Matthew Tyler Osborne, Ph.D.'s original authorship and sponsorship of the Erdős Institute as subject to the license (see License.md)
